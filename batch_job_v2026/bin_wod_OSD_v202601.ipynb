# %% [markdown]
# # WOD CTD: global 1x1 bin
# - annual netCDF output
# - WOD OSD data
# - 1965 to 2025

# %%
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc
import xarray as xr
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')

# %%
# data source identification
Nlev=102
dctd='/glade/campaign/univ/ugit0034/Zhankun/202601/Oxygen_OSD_'
dirname='/glade/derecho/scratch/ito/temporary_WOD_output/'
varname='Oxygen'

# %%
# uncomment for 2000m depth
year=1965
ds=xr.open_dataset(f'{dctd}{year}.nc')
z0=ds.depth.to_numpy()
zwod=np.unique(z0)[:Nlev]
zwod
# Out:
# array([0.00e+00, 5.00e+00, 1.00e+01, 1.50e+01, 2.00e+01, 2.50e+01,
#        3.00e+01, 3.50e+01, 4.00e+01, 4.50e+01, 5.00e+01, 5.50e+01,
#        6.00e+01, 6.50e+01, 7.00e+01, 7.50e+01, 8.00e+01, 8.50e+01,
#        9.00e+01, 9.50e+01, 1.00e+02, 1.25e+02, 1.50e+02, 1.75e+02,
#        2.00e+02, 2.25e+02, 2.50e+02, 2.75e+02, 3.00e+02, 3.25e+02,
#        3.50e+02, 3.75e+02, 4.00e+02, 4.25e+02, 4.50e+02, 4.75e+02,
#        5.00e+02, 5.50e+02, 6.00e+02, 6.50e+02, 7.00e+02, 7.50e+02,
#        8.00e+02, 8.50e+02, 9.00e+02, 9.50e+02, 1.00e+03, 1.05e+03,
#        1.10e+03, 1.15e+03, 1.20e+03, 1.25e+03, 1.30e+03, 1.35e+03,
#        1.40e+03, 1.45e+03, 1.50e+03, 1.55e+03, 1.60e+03, 1.65e+03,
#        1.70e+03, 1.75e+03, 1.80e+03, 1.85e+03, 1.90e+03, 1.95e+03,
#        2.00e+03, 2.10e+03, 2.20e+03, 2.30e+03, 2.40e+03, 2.50e+03,
#        2.60e+03, 2.70e+03, 2.80e+03, 2.90e+03, 3.00e+03, 3.10e+03,
#        3.20e+03, 3.30e+03, 3.40e+03, 3.50e+03, 3.60e+03, 3.70e+03,
#        3.80e+03, 3.90e+03, 4.00e+03, 4.10e+03, 4.20e+03, 4.30e+03,
#        4.40e+03, 4.50e+03, 4.60e+03, 4.70e+03, 4.80e+03, 4.90e+03,
#        5.00e+03, 5.10e+03, 5.20e+03, 5.30e+03, 5.40e+03, 5.50e+03])

# %%
##os.system('rm -rf '+dirname)
os.system('mkdir -p '+dirname)
# Out:
# 0

# %%
# prepare grid cells
res=1
xW=np.arange(-180,180,res)
yS=np.arange(-90,90,res)
xC=np.arange(-180,180,res)+res/2
yC=np.arange(-90,90,res)+res/2
xE=np.arange(-180,180,res)+res
yN=np.arange(-90,90,res)+res
# empty array
Nx=np.size(xC)
Ny=np.size(yC)
#
z=zwod
Nz=np.size(z)
Nx=np.size(xC)
Ny=np.size(yC)

# %%
def monthly_1deg_bin(Nlev,year,varname):
    # prepare array
    dd_osd=np.zeros((12,Nlev,Ny,Nx),dtype='int')
    sumX_osd=np.zeros((12,Nlev,Ny,Nx))
    # set 1deg lon-lat grid
    Xw=np.arange(-180,180,res)
    Ys=np.arange(-90,90,res)
    # loop over each WOD ragged netCDF file
    dsosd=xr.open_dataset(f'{dctd}{year}.nc')
    Nprof0 = np.size(dsosd.profile)
    print('num of prof = '+str(Nprof0))
    print('reading data...')
    for n in range(Nprof0):
        lonloc=dsosd['lon'][n].to_numpy()+1e-6
        latloc=dsosd['lat'][n].to_numpy()+1e-6
        #print(lonloc,latloc)
        # get tracer data
        o2p0=dsosd[varname][n,:Nlev].to_numpy()
        #print(o2p0)
        # get month 
        monloc = dsosd['month'][n].to_numpy()
        mind=int(monloc-1)
        if (abs(lonloc)>180)|(abs(latloc)>90):
            lonloc=-179.99
            latloc=-89.99
            baddata=1
        else:
            baddata=0
        xind=np.where((Xw>=lonloc-res)&(Xw<lonloc))[0][0]
        yind=np.where((Ys>=latloc-res)&(Ys<latloc))[0][0]
        if (baddata==1):
            tmp_note='no data'
        else:
            # get the profile and its quality flag
            o2p1=np.where(np.isnan(o2p0),0,o2p0)
            pcnt=np.where(np.isnan(o2p0),0,1)
            #print(o2p1)
            #print(pcnt)
            sumX_osd[mind,:,yind,xind]=sumX_osd[mind,:,yind,xind]+o2p1
            dd_osd[mind,:,yind,xind]=dd_osd[mind,:,yind,xind]+pcnt
    return sumX_osd,dd_osd

# %%
def save_1deg_bin(dsum,dd,xc,yc,zc,year,var):
    fn=dirname+'/'+var+f'_1x1bin_osd_'+str(year)+'.nc'
    dave=dsum/dd
    mon=np.arange(f'{year}-01',f'{year+1}-01',dtype='datetime64[M]')
    da=xr.DataArray(data=dave,name=var,dims=['time','depth','lat','lon'],\
                coords={'time':mon,'depth':zc,'lat':yc,'lon':xc})
    ds=da.to_dataset()
    dd=xr.DataArray(data=dd,name='sample_count',dims=['time','depth','lat','lon'],\
                    coords={'time':mon,'depth':zc,'lat':yc,'lon':xc})
    ds['sample_count']=dd
    ds.to_netcdf(fn)
    return 1

# %%
YR=np.arange(1965,2026,1)
#
xc=xC.copy()
yc=yC.copy()
zc=z.copy()
#
for yr in YR:
    print('=== working on '+str(yr)+' ===')
    sumX,dd=monthly_1deg_bin(Nlev,yr,varname)
    dummy=save_1deg_bin(sumX,dd,xc,yc,zc,yr,varname)
# Out:
# === working on 1965 ===
# num of prof = 17371
# reading data...
# === working on 1966 ===
# num of prof = 17580
# reading data...
# === working on 1967 ===
# num of prof = 17689
# reading data...
# === working on 1968 ===
# num of prof = 17960
# reading data...
# === working on 1969 ===
# num of prof = 19895
# reading data...
# === working on 1970 ===
# num of prof = 18116
# reading data...
# === working on 1971 ===
# num of prof = 20421
# reading data...
# === working on 1972 ===
# num of prof = 22987
# reading data...
# === working on 1973 ===
# num of prof = 22836
# reading data...
# === working on 1974 ===
# num of prof = 19215
# reading data...
# === working on 1975 ===
# num of prof = 18411
# reading data...
# === working on 1976 ===
# num of prof = 20460
# reading data...
# === working on 1977 ===
# num of prof = 19091
# reading data...
# === working on 1978 ===
# num of prof = 20356
# reading data...
# === working on 1979 ===
# num of prof = 17372
# reading data...
# === working on 1980 ===
# num of prof = 20248
# reading data...
# === working on 1981 ===
# num of prof = 18843
# reading data...
# === working on 1982 ===
# num of prof = 17646
# reading data...
# === working on 1983 ===
# num of prof = 18495
# reading data...
# === working on 1984 ===
# num of prof = 20006
# reading data...
# === working on 1985 ===
# num of prof = 16823
# reading data...
# === working on 1986 ===
# num of prof = 18145
# reading data...
# === working on 1987 ===
# num of prof = 19740
# reading data...
# === working on 1988 ===
# num of prof = 19703
# reading data...
# === working on 1994 ===
# num of prof = 8758
# reading data...
# === working on 1995 ===
# num of prof = 10167
# reading data...
# === working on 1996 ===
# num of prof = 8000
# reading data...
# === working on 1997 ===
# num of prof = 9444
# reading data...
# === working on 1998 ===
# num of prof = 8011
# reading data...
# === working on 1999 ===
# num of prof = 7641
# reading data...
# === working on 2000 ===
# num of prof = 8802
# reading data...
# === working on 2001 ===
# num of prof = 10031
# reading data...
# === working on 2002 ===
# num of prof = 8813
# reading data...
# === working on 2003 ===
# num of prof = 7444
# reading data...
# === working on 2004 ===
# num of prof = 7873
# reading data...
# === working on 2005 ===
# num of prof = 7300
# reading data...
# === working on 2006 ===
# num of prof = 7605
# reading data...
# === working on 2007 ===
# num of prof = 6582
# reading data...
# === working on 2008 ===
# num of prof = 7087
# reading data...
# === working on 2009 ===
# num of prof = 4779
# reading data...
# === working on 2010 ===
# num of prof = 4641
# reading data...
# === working on 2011 ===
# num of prof = 3160
# reading data...
# === working on 2012 ===
# num of prof = 3661
# reading data...
# === working on 2013 ===
# num of prof = 7071
# reading data...
# === working on 2014 ===
# num of prof = 6167
# reading data...
# === working on 2015 ===
# num of prof = 6883
# reading data...
# === working on 2016 ===
# num of prof = 6880
# reading data...
# === working on 2017 ===
# num of prof = 6382
# reading data...
# === working on 2018 ===
# num of prof = 2124
# reading data...
# === working on 2019 ===
# num of prof = 1454
# reading data...
# === working on 2020 ===
# num of prof = 275
# reading data...
# === working on 2021 ===
# num of prof = 501
# reading data...
# === working on 2022 ===
# num of prof = 362
# reading data...
# === working on 2023 ===
# num of prof = 406
# reading data...
# === working on 2024 ===
# num of prof = 176
# reading data...
# === working on 2025 ===
# num of prof = 92
# reading data...

# %%
ds=xr.open_mfdataset(dirname+'/'+varname+'_1x1bin_osd_*.nc')

# %%
ds[varname][:,0,:,:].mean('time').plot()

# %%
ds.to_netcdf(dirname+varname+f'_{res}x{res}bin_osd_1965-2025.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 732, depth: 102, lat: 180, lon: 360)
# Coordinates:
#   * time          (time) datetime64[ns] 1965-01-01 1965-02-01 ... 2025-12-01
#   * depth         (depth) float64 0.0 5.0 10.0 15.0 ... 5.3e+03 5.4e+03 5.5e+03
#   * lat           (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * lon           (lon) float64 -179.5 -178.5 -177.5 ... 177.5 178.5 179.5
# Data variables:
#     Oxygen        (time, depth, lat, lon) float64 dask.array<chunksize=(12, 102, 180, 360), meta=np.ndarray>
#     sample_count  (time, depth, lat, lon) int64 dask.array<chunksize=(12, 102, 180, 360), meta=np.ndarray>
