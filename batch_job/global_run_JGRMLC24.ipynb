# %% [markdown]
# # global run

# %%
import numpy as np
import os
import time

# %%
cnt=0
for n3 in np.arange(1,6,1):
    for n2 in np.arange(1,3,1):
        for n1 in np.arange(1,3,1):
            for n5 in np.arange(2,5,1):
                cnt=cnt+1
                vnow=f'{n1}.{n2}.{n3}.1.{n5}.4'
                com =f'echo \'{vnow}\' > data_{cnt}.txt'
                print(com)
                com = f'cp run.pbs run{cnt}.pbs'
                print(com)
                com = f'sed -i \'s/o2_train.py/o2_train{cnt}.py/g\' run{cnt}.pbs'
                print(com)
                com = f'sed -i \'s/o2_eval.py/o2_eval{cnt}.py/g\' run{cnt}.pbs'
                print(com)
                com = f'sed -i \'s/o2_project.py/o2_project{cnt}.py/g\' run{cnt}.pbs'
                print(com)
                com = f'sed -i \'s/map_o2_XXX/map_o2_{cnt}/g\' run{cnt}.pbs'
                print(com)
                com = f'cp o2_train.py o2_train{cnt}.py'
                print(com)
                com = f'cp o2_eval.py o2_eval{cnt}.py'
                print(com)
                com = f'cp o2_project.py o2_project{cnt}.py'
                print(com)
                com = f'sed -i \'s/data_XXX/data_{cnt}/g\' o2_train{cnt}.py'
                print(com)
                com = f'sed -i \'s/data_XXX/data_{cnt}/g\' o2_eval{cnt}.py'
                print(com)
                com = f'sed -i \'s/data_XXX/data_{cnt}/g\' o2_project{cnt}.py'
                print(com)
                com = f'qsub run{cnt}.pbs'
                print(com)
                print('sleep 3')
                print('#--------------------------------------------------------')
# Out:
# echo '1.1.1.1.2.4' > data_1.txt
# cp run.pbs run1.pbs
# sed -i 's/o2_train.py/o2_train1.py/g' run1.pbs
# sed -i 's/o2_eval.py/o2_eval1.py/g' run1.pbs
# sed -i 's/o2_project.py/o2_project1.py/g' run1.pbs
# sed -i 's/map_o2_XXX/map_o2_1/g' run1.pbs
# cp o2_train.py o2_train1.py
# cp o2_eval.py o2_eval1.py
# cp o2_project.py o2_project1.py
# sed -i 's/data_XXX/data_1/g' o2_train1.py
# sed -i 's/data_XXX/data_1/g' o2_eval1.py
# sed -i 's/data_XXX/data_1/g' o2_project1.py
# qsub run1.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.1.1.3.4' > data_2.txt
# cp run.pbs run2.pbs
# sed -i 's/o2_train.py/o2_train2.py/g' run2.pbs
# sed -i 's/o2_eval.py/o2_eval2.py/g' run2.pbs
# sed -i 's/o2_project.py/o2_project2.py/g' run2.pbs
# sed -i 's/map_o2_XXX/map_o2_2/g' run2.pbs
# cp o2_train.py o2_train2.py
# cp o2_eval.py o2_eval2.py
# cp o2_project.py o2_project2.py
# sed -i 's/data_XXX/data_2/g' o2_train2.py
# sed -i 's/data_XXX/data_2/g' o2_eval2.py
# sed -i 's/data_XXX/data_2/g' o2_project2.py
# qsub run2.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.1.1.4.4' > data_3.txt
# cp run.pbs run3.pbs
# sed -i 's/o2_train.py/o2_train3.py/g' run3.pbs
# sed -i 's/o2_eval.py/o2_eval3.py/g' run3.pbs
# sed -i 's/o2_project.py/o2_project3.py/g' run3.pbs
# sed -i 's/map_o2_XXX/map_o2_3/g' run3.pbs
# cp o2_train.py o2_train3.py
# cp o2_eval.py o2_eval3.py
# cp o2_project.py o2_project3.py
# sed -i 's/data_XXX/data_3/g' o2_train3.py
# sed -i 's/data_XXX/data_3/g' o2_eval3.py
# sed -i 's/data_XXX/data_3/g' o2_project3.py
# qsub run3.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.1.1.2.4' > data_4.txt
# cp run.pbs run4.pbs
# sed -i 's/o2_train.py/o2_train4.py/g' run4.pbs
# sed -i 's/o2_eval.py/o2_eval4.py/g' run4.pbs
# sed -i 's/o2_project.py/o2_project4.py/g' run4.pbs
# sed -i 's/map_o2_XXX/map_o2_4/g' run4.pbs
# cp o2_train.py o2_train4.py
# cp o2_eval.py o2_eval4.py
# cp o2_project.py o2_project4.py
# sed -i 's/data_XXX/data_4/g' o2_train4.py
# sed -i 's/data_XXX/data_4/g' o2_eval4.py
# sed -i 's/data_XXX/data_4/g' o2_project4.py
# qsub run4.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.1.1.3.4' > data_5.txt
# cp run.pbs run5.pbs
# sed -i 's/o2_train.py/o2_train5.py/g' run5.pbs
# sed -i 's/o2_eval.py/o2_eval5.py/g' run5.pbs
# sed -i 's/o2_project.py/o2_project5.py/g' run5.pbs
# sed -i 's/map_o2_XXX/map_o2_5/g' run5.pbs
# cp o2_train.py o2_train5.py
# cp o2_eval.py o2_eval5.py
# cp o2_project.py o2_project5.py
# sed -i 's/data_XXX/data_5/g' o2_train5.py
# sed -i 's/data_XXX/data_5/g' o2_eval5.py
# sed -i 's/data_XXX/data_5/g' o2_project5.py
# qsub run5.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.1.1.4.4' > data_6.txt
# cp run.pbs run6.pbs
# sed -i 's/o2_train.py/o2_train6.py/g' run6.pbs
# sed -i 's/o2_eval.py/o2_eval6.py/g' run6.pbs
# sed -i 's/o2_project.py/o2_project6.py/g' run6.pbs
# sed -i 's/map_o2_XXX/map_o2_6/g' run6.pbs
# cp o2_train.py o2_train6.py
# cp o2_eval.py o2_eval6.py
# cp o2_project.py o2_project6.py
# sed -i 's/data_XXX/data_6/g' o2_train6.py
# sed -i 's/data_XXX/data_6/g' o2_eval6.py
# sed -i 's/data_XXX/data_6/g' o2_project6.py
# qsub run6.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.1.1.2.4' > data_7.txt
# cp run.pbs run7.pbs
# sed -i 's/o2_train.py/o2_train7.py/g' run7.pbs
# sed -i 's/o2_eval.py/o2_eval7.py/g' run7.pbs
# sed -i 's/o2_project.py/o2_project7.py/g' run7.pbs
# sed -i 's/map_o2_XXX/map_o2_7/g' run7.pbs
# cp o2_train.py o2_train7.py
# cp o2_eval.py o2_eval7.py
# cp o2_project.py o2_project7.py
# sed -i 's/data_XXX/data_7/g' o2_train7.py
# sed -i 's/data_XXX/data_7/g' o2_eval7.py
# sed -i 's/data_XXX/data_7/g' o2_project7.py
# qsub run7.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.1.1.3.4' > data_8.txt
# cp run.pbs run8.pbs
# sed -i 's/o2_train.py/o2_train8.py/g' run8.pbs
# sed -i 's/o2_eval.py/o2_eval8.py/g' run8.pbs
# sed -i 's/o2_project.py/o2_project8.py/g' run8.pbs
# sed -i 's/map_o2_XXX/map_o2_8/g' run8.pbs
# cp o2_train.py o2_train8.py
# cp o2_eval.py o2_eval8.py
# cp o2_project.py o2_project8.py
# sed -i 's/data_XXX/data_8/g' o2_train8.py
# sed -i 's/data_XXX/data_8/g' o2_eval8.py
# sed -i 's/data_XXX/data_8/g' o2_project8.py
# qsub run8.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.1.1.4.4' > data_9.txt
# cp run.pbs run9.pbs
# sed -i 's/o2_train.py/o2_train9.py/g' run9.pbs
# sed -i 's/o2_eval.py/o2_eval9.py/g' run9.pbs
# sed -i 's/o2_project.py/o2_project9.py/g' run9.pbs
# sed -i 's/map_o2_XXX/map_o2_9/g' run9.pbs
# cp o2_train.py o2_train9.py
# cp o2_eval.py o2_eval9.py
# cp o2_project.py o2_project9.py
# sed -i 's/data_XXX/data_9/g' o2_train9.py
# sed -i 's/data_XXX/data_9/g' o2_eval9.py
# sed -i 's/data_XXX/data_9/g' o2_project9.py
# qsub run9.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.1.1.2.4' > data_10.txt
# cp run.pbs run10.pbs
# sed -i 's/o2_train.py/o2_train10.py/g' run10.pbs
# sed -i 's/o2_eval.py/o2_eval10.py/g' run10.pbs
# sed -i 's/o2_project.py/o2_project10.py/g' run10.pbs
# sed -i 's/map_o2_XXX/map_o2_10/g' run10.pbs
# cp o2_train.py o2_train10.py
# cp o2_eval.py o2_eval10.py
# cp o2_project.py o2_project10.py
# sed -i 's/data_XXX/data_10/g' o2_train10.py
# sed -i 's/data_XXX/data_10/g' o2_eval10.py
# sed -i 's/data_XXX/data_10/g' o2_project10.py
# qsub run10.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.1.1.3.4' > data_11.txt
# cp run.pbs run11.pbs
# sed -i 's/o2_train.py/o2_train11.py/g' run11.pbs
# sed -i 's/o2_eval.py/o2_eval11.py/g' run11.pbs
# sed -i 's/o2_project.py/o2_project11.py/g' run11.pbs
# sed -i 's/map_o2_XXX/map_o2_11/g' run11.pbs
# cp o2_train.py o2_train11.py
# cp o2_eval.py o2_eval11.py
# cp o2_project.py o2_project11.py
# sed -i 's/data_XXX/data_11/g' o2_train11.py
# sed -i 's/data_XXX/data_11/g' o2_eval11.py
# sed -i 's/data_XXX/data_11/g' o2_project11.py
# qsub run11.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.1.1.4.4' > data_12.txt
# cp run.pbs run12.pbs
# sed -i 's/o2_train.py/o2_train12.py/g' run12.pbs
# sed -i 's/o2_eval.py/o2_eval12.py/g' run12.pbs
# sed -i 's/o2_project.py/o2_project12.py/g' run12.pbs
# sed -i 's/map_o2_XXX/map_o2_12/g' run12.pbs
# cp o2_train.py o2_train12.py
# cp o2_eval.py o2_eval12.py
# cp o2_project.py o2_project12.py
# sed -i 's/data_XXX/data_12/g' o2_train12.py
# sed -i 's/data_XXX/data_12/g' o2_eval12.py
# sed -i 's/data_XXX/data_12/g' o2_project12.py
# qsub run12.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.2.1.2.4' > data_13.txt
# cp run.pbs run13.pbs
# sed -i 's/o2_train.py/o2_train13.py/g' run13.pbs
# sed -i 's/o2_eval.py/o2_eval13.py/g' run13.pbs
# sed -i 's/o2_project.py/o2_project13.py/g' run13.pbs
# sed -i 's/map_o2_XXX/map_o2_13/g' run13.pbs
# cp o2_train.py o2_train13.py
# cp o2_eval.py o2_eval13.py
# cp o2_project.py o2_project13.py
# sed -i 's/data_XXX/data_13/g' o2_train13.py
# sed -i 's/data_XXX/data_13/g' o2_eval13.py
# sed -i 's/data_XXX/data_13/g' o2_project13.py
# qsub run13.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.2.1.3.4' > data_14.txt
# cp run.pbs run14.pbs
# sed -i 's/o2_train.py/o2_train14.py/g' run14.pbs
# sed -i 's/o2_eval.py/o2_eval14.py/g' run14.pbs
# sed -i 's/o2_project.py/o2_project14.py/g' run14.pbs
# sed -i 's/map_o2_XXX/map_o2_14/g' run14.pbs
# cp o2_train.py o2_train14.py
# cp o2_eval.py o2_eval14.py
# cp o2_project.py o2_project14.py
# sed -i 's/data_XXX/data_14/g' o2_train14.py
# sed -i 's/data_XXX/data_14/g' o2_eval14.py
# sed -i 's/data_XXX/data_14/g' o2_project14.py
# qsub run14.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.2.1.4.4' > data_15.txt
# cp run.pbs run15.pbs
# sed -i 's/o2_train.py/o2_train15.py/g' run15.pbs
# sed -i 's/o2_eval.py/o2_eval15.py/g' run15.pbs
# sed -i 's/o2_project.py/o2_project15.py/g' run15.pbs
# sed -i 's/map_o2_XXX/map_o2_15/g' run15.pbs
# cp o2_train.py o2_train15.py
# cp o2_eval.py o2_eval15.py
# cp o2_project.py o2_project15.py
# sed -i 's/data_XXX/data_15/g' o2_train15.py
# sed -i 's/data_XXX/data_15/g' o2_eval15.py
# sed -i 's/data_XXX/data_15/g' o2_project15.py
# qsub run15.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.2.1.2.4' > data_16.txt
# cp run.pbs run16.pbs
# sed -i 's/o2_train.py/o2_train16.py/g' run16.pbs
# sed -i 's/o2_eval.py/o2_eval16.py/g' run16.pbs
# sed -i 's/o2_project.py/o2_project16.py/g' run16.pbs
# sed -i 's/map_o2_XXX/map_o2_16/g' run16.pbs
# cp o2_train.py o2_train16.py
# cp o2_eval.py o2_eval16.py
# cp o2_project.py o2_project16.py
# sed -i 's/data_XXX/data_16/g' o2_train16.py
# sed -i 's/data_XXX/data_16/g' o2_eval16.py
# sed -i 's/data_XXX/data_16/g' o2_project16.py
# qsub run16.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.2.1.3.4' > data_17.txt
# cp run.pbs run17.pbs
# sed -i 's/o2_train.py/o2_train17.py/g' run17.pbs
# sed -i 's/o2_eval.py/o2_eval17.py/g' run17.pbs
# sed -i 's/o2_project.py/o2_project17.py/g' run17.pbs
# sed -i 's/map_o2_XXX/map_o2_17/g' run17.pbs
# cp o2_train.py o2_train17.py
# cp o2_eval.py o2_eval17.py
# cp o2_project.py o2_project17.py
# sed -i 's/data_XXX/data_17/g' o2_train17.py
# sed -i 's/data_XXX/data_17/g' o2_eval17.py
# sed -i 's/data_XXX/data_17/g' o2_project17.py
# qsub run17.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.2.1.4.4' > data_18.txt
# cp run.pbs run18.pbs
# sed -i 's/o2_train.py/o2_train18.py/g' run18.pbs
# sed -i 's/o2_eval.py/o2_eval18.py/g' run18.pbs
# sed -i 's/o2_project.py/o2_project18.py/g' run18.pbs
# sed -i 's/map_o2_XXX/map_o2_18/g' run18.pbs
# cp o2_train.py o2_train18.py
# cp o2_eval.py o2_eval18.py
# cp o2_project.py o2_project18.py
# sed -i 's/data_XXX/data_18/g' o2_train18.py
# sed -i 's/data_XXX/data_18/g' o2_eval18.py
# sed -i 's/data_XXX/data_18/g' o2_project18.py
# qsub run18.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.2.1.2.4' > data_19.txt
# cp run.pbs run19.pbs
# sed -i 's/o2_train.py/o2_train19.py/g' run19.pbs
# sed -i 's/o2_eval.py/o2_eval19.py/g' run19.pbs
# sed -i 's/o2_project.py/o2_project19.py/g' run19.pbs
# sed -i 's/map_o2_XXX/map_o2_19/g' run19.pbs
# cp o2_train.py o2_train19.py
# cp o2_eval.py o2_eval19.py
# cp o2_project.py o2_project19.py
# sed -i 's/data_XXX/data_19/g' o2_train19.py
# sed -i 's/data_XXX/data_19/g' o2_eval19.py
# sed -i 's/data_XXX/data_19/g' o2_project19.py
# qsub run19.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.2.1.3.4' > data_20.txt
# cp run.pbs run20.pbs
# sed -i 's/o2_train.py/o2_train20.py/g' run20.pbs
# sed -i 's/o2_eval.py/o2_eval20.py/g' run20.pbs
# sed -i 's/o2_project.py/o2_project20.py/g' run20.pbs
# sed -i 's/map_o2_XXX/map_o2_20/g' run20.pbs
# cp o2_train.py o2_train20.py
# cp o2_eval.py o2_eval20.py
# cp o2_project.py o2_project20.py
# sed -i 's/data_XXX/data_20/g' o2_train20.py
# sed -i 's/data_XXX/data_20/g' o2_eval20.py
# sed -i 's/data_XXX/data_20/g' o2_project20.py
# qsub run20.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.2.1.4.4' > data_21.txt
# cp run.pbs run21.pbs
# sed -i 's/o2_train.py/o2_train21.py/g' run21.pbs
# sed -i 's/o2_eval.py/o2_eval21.py/g' run21.pbs
# sed -i 's/o2_project.py/o2_project21.py/g' run21.pbs
# sed -i 's/map_o2_XXX/map_o2_21/g' run21.pbs
# cp o2_train.py o2_train21.py
# cp o2_eval.py o2_eval21.py
# cp o2_project.py o2_project21.py
# sed -i 's/data_XXX/data_21/g' o2_train21.py
# sed -i 's/data_XXX/data_21/g' o2_eval21.py
# sed -i 's/data_XXX/data_21/g' o2_project21.py
# qsub run21.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.2.1.2.4' > data_22.txt
# cp run.pbs run22.pbs
# sed -i 's/o2_train.py/o2_train22.py/g' run22.pbs
# sed -i 's/o2_eval.py/o2_eval22.py/g' run22.pbs
# sed -i 's/o2_project.py/o2_project22.py/g' run22.pbs
# sed -i 's/map_o2_XXX/map_o2_22/g' run22.pbs
# cp o2_train.py o2_train22.py
# cp o2_eval.py o2_eval22.py
# cp o2_project.py o2_project22.py
# sed -i 's/data_XXX/data_22/g' o2_train22.py
# sed -i 's/data_XXX/data_22/g' o2_eval22.py
# sed -i 's/data_XXX/data_22/g' o2_project22.py
# qsub run22.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.2.1.3.4' > data_23.txt
# cp run.pbs run23.pbs
# sed -i 's/o2_train.py/o2_train23.py/g' run23.pbs
# sed -i 's/o2_eval.py/o2_eval23.py/g' run23.pbs
# sed -i 's/o2_project.py/o2_project23.py/g' run23.pbs
# sed -i 's/map_o2_XXX/map_o2_23/g' run23.pbs
# cp o2_train.py o2_train23.py
# cp o2_eval.py o2_eval23.py
# cp o2_project.py o2_project23.py
# sed -i 's/data_XXX/data_23/g' o2_train23.py
# sed -i 's/data_XXX/data_23/g' o2_eval23.py
# sed -i 's/data_XXX/data_23/g' o2_project23.py
# qsub run23.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.2.1.4.4' > data_24.txt
# cp run.pbs run24.pbs
# sed -i 's/o2_train.py/o2_train24.py/g' run24.pbs
# sed -i 's/o2_eval.py/o2_eval24.py/g' run24.pbs
# sed -i 's/o2_project.py/o2_project24.py/g' run24.pbs
# sed -i 's/map_o2_XXX/map_o2_24/g' run24.pbs
# cp o2_train.py o2_train24.py
# cp o2_eval.py o2_eval24.py
# cp o2_project.py o2_project24.py
# sed -i 's/data_XXX/data_24/g' o2_train24.py
# sed -i 's/data_XXX/data_24/g' o2_eval24.py
# sed -i 's/data_XXX/data_24/g' o2_project24.py
# qsub run24.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.3.1.2.4' > data_25.txt
# cp run.pbs run25.pbs
# sed -i 's/o2_train.py/o2_train25.py/g' run25.pbs
# sed -i 's/o2_eval.py/o2_eval25.py/g' run25.pbs
# sed -i 's/o2_project.py/o2_project25.py/g' run25.pbs
# sed -i 's/map_o2_XXX/map_o2_25/g' run25.pbs
# cp o2_train.py o2_train25.py
# cp o2_eval.py o2_eval25.py
# cp o2_project.py o2_project25.py
# sed -i 's/data_XXX/data_25/g' o2_train25.py
# sed -i 's/data_XXX/data_25/g' o2_eval25.py
# sed -i 's/data_XXX/data_25/g' o2_project25.py
# qsub run25.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.3.1.3.4' > data_26.txt
# cp run.pbs run26.pbs
# sed -i 's/o2_train.py/o2_train26.py/g' run26.pbs
# sed -i 's/o2_eval.py/o2_eval26.py/g' run26.pbs
# sed -i 's/o2_project.py/o2_project26.py/g' run26.pbs
# sed -i 's/map_o2_XXX/map_o2_26/g' run26.pbs
# cp o2_train.py o2_train26.py
# cp o2_eval.py o2_eval26.py
# cp o2_project.py o2_project26.py
# sed -i 's/data_XXX/data_26/g' o2_train26.py
# sed -i 's/data_XXX/data_26/g' o2_eval26.py
# sed -i 's/data_XXX/data_26/g' o2_project26.py
# qsub run26.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.3.1.4.4' > data_27.txt
# cp run.pbs run27.pbs
# sed -i 's/o2_train.py/o2_train27.py/g' run27.pbs
# sed -i 's/o2_eval.py/o2_eval27.py/g' run27.pbs
# sed -i 's/o2_project.py/o2_project27.py/g' run27.pbs
# sed -i 's/map_o2_XXX/map_o2_27/g' run27.pbs
# cp o2_train.py o2_train27.py
# cp o2_eval.py o2_eval27.py
# cp o2_project.py o2_project27.py
# sed -i 's/data_XXX/data_27/g' o2_train27.py
# sed -i 's/data_XXX/data_27/g' o2_eval27.py
# sed -i 's/data_XXX/data_27/g' o2_project27.py
# qsub run27.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.3.1.2.4' > data_28.txt
# cp run.pbs run28.pbs
# sed -i 's/o2_train.py/o2_train28.py/g' run28.pbs
# sed -i 's/o2_eval.py/o2_eval28.py/g' run28.pbs
# sed -i 's/o2_project.py/o2_project28.py/g' run28.pbs
# sed -i 's/map_o2_XXX/map_o2_28/g' run28.pbs
# cp o2_train.py o2_train28.py
# cp o2_eval.py o2_eval28.py
# cp o2_project.py o2_project28.py
# sed -i 's/data_XXX/data_28/g' o2_train28.py
# sed -i 's/data_XXX/data_28/g' o2_eval28.py
# sed -i 's/data_XXX/data_28/g' o2_project28.py
# qsub run28.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.3.1.3.4' > data_29.txt
# cp run.pbs run29.pbs
# sed -i 's/o2_train.py/o2_train29.py/g' run29.pbs
# sed -i 's/o2_eval.py/o2_eval29.py/g' run29.pbs
# sed -i 's/o2_project.py/o2_project29.py/g' run29.pbs
# sed -i 's/map_o2_XXX/map_o2_29/g' run29.pbs
# cp o2_train.py o2_train29.py
# cp o2_eval.py o2_eval29.py
# cp o2_project.py o2_project29.py
# sed -i 's/data_XXX/data_29/g' o2_train29.py
# sed -i 's/data_XXX/data_29/g' o2_eval29.py
# sed -i 's/data_XXX/data_29/g' o2_project29.py
# qsub run29.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.3.1.4.4' > data_30.txt
# cp run.pbs run30.pbs
# sed -i 's/o2_train.py/o2_train30.py/g' run30.pbs
# sed -i 's/o2_eval.py/o2_eval30.py/g' run30.pbs
# sed -i 's/o2_project.py/o2_project30.py/g' run30.pbs
# sed -i 's/map_o2_XXX/map_o2_30/g' run30.pbs
# cp o2_train.py o2_train30.py
# cp o2_eval.py o2_eval30.py
# cp o2_project.py o2_project30.py
# sed -i 's/data_XXX/data_30/g' o2_train30.py
# sed -i 's/data_XXX/data_30/g' o2_eval30.py
# sed -i 's/data_XXX/data_30/g' o2_project30.py
# qsub run30.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.3.1.2.4' > data_31.txt
# cp run.pbs run31.pbs
# sed -i 's/o2_train.py/o2_train31.py/g' run31.pbs
# sed -i 's/o2_eval.py/o2_eval31.py/g' run31.pbs
# sed -i 's/o2_project.py/o2_project31.py/g' run31.pbs
# sed -i 's/map_o2_XXX/map_o2_31/g' run31.pbs
# cp o2_train.py o2_train31.py
# cp o2_eval.py o2_eval31.py
# cp o2_project.py o2_project31.py
# sed -i 's/data_XXX/data_31/g' o2_train31.py
# sed -i 's/data_XXX/data_31/g' o2_eval31.py
# sed -i 's/data_XXX/data_31/g' o2_project31.py
# qsub run31.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.3.1.3.4' > data_32.txt
# cp run.pbs run32.pbs
# sed -i 's/o2_train.py/o2_train32.py/g' run32.pbs
# sed -i 's/o2_eval.py/o2_eval32.py/g' run32.pbs
# sed -i 's/o2_project.py/o2_project32.py/g' run32.pbs
# sed -i 's/map_o2_XXX/map_o2_32/g' run32.pbs
# cp o2_train.py o2_train32.py
# cp o2_eval.py o2_eval32.py
# cp o2_project.py o2_project32.py
# sed -i 's/data_XXX/data_32/g' o2_train32.py
# sed -i 's/data_XXX/data_32/g' o2_eval32.py
# sed -i 's/data_XXX/data_32/g' o2_project32.py
# qsub run32.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.3.1.4.4' > data_33.txt
# cp run.pbs run33.pbs
# sed -i 's/o2_train.py/o2_train33.py/g' run33.pbs
# sed -i 's/o2_eval.py/o2_eval33.py/g' run33.pbs
# sed -i 's/o2_project.py/o2_project33.py/g' run33.pbs
# sed -i 's/map_o2_XXX/map_o2_33/g' run33.pbs
# cp o2_train.py o2_train33.py
# cp o2_eval.py o2_eval33.py
# cp o2_project.py o2_project33.py
# sed -i 's/data_XXX/data_33/g' o2_train33.py
# sed -i 's/data_XXX/data_33/g' o2_eval33.py
# sed -i 's/data_XXX/data_33/g' o2_project33.py
# qsub run33.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.3.1.2.4' > data_34.txt
# cp run.pbs run34.pbs
# sed -i 's/o2_train.py/o2_train34.py/g' run34.pbs
# sed -i 's/o2_eval.py/o2_eval34.py/g' run34.pbs
# sed -i 's/o2_project.py/o2_project34.py/g' run34.pbs
# sed -i 's/map_o2_XXX/map_o2_34/g' run34.pbs
# cp o2_train.py o2_train34.py
# cp o2_eval.py o2_eval34.py
# cp o2_project.py o2_project34.py
# sed -i 's/data_XXX/data_34/g' o2_train34.py
# sed -i 's/data_XXX/data_34/g' o2_eval34.py
# sed -i 's/data_XXX/data_34/g' o2_project34.py
# qsub run34.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.3.1.3.4' > data_35.txt
# cp run.pbs run35.pbs
# sed -i 's/o2_train.py/o2_train35.py/g' run35.pbs
# sed -i 's/o2_eval.py/o2_eval35.py/g' run35.pbs
# sed -i 's/o2_project.py/o2_project35.py/g' run35.pbs
# sed -i 's/map_o2_XXX/map_o2_35/g' run35.pbs
# cp o2_train.py o2_train35.py
# cp o2_eval.py o2_eval35.py
# cp o2_project.py o2_project35.py
# sed -i 's/data_XXX/data_35/g' o2_train35.py
# sed -i 's/data_XXX/data_35/g' o2_eval35.py
# sed -i 's/data_XXX/data_35/g' o2_project35.py
# qsub run35.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.3.1.4.4' > data_36.txt
# cp run.pbs run36.pbs
# sed -i 's/o2_train.py/o2_train36.py/g' run36.pbs
# sed -i 's/o2_eval.py/o2_eval36.py/g' run36.pbs
# sed -i 's/o2_project.py/o2_project36.py/g' run36.pbs
# sed -i 's/map_o2_XXX/map_o2_36/g' run36.pbs
# cp o2_train.py o2_train36.py
# cp o2_eval.py o2_eval36.py
# cp o2_project.py o2_project36.py
# sed -i 's/data_XXX/data_36/g' o2_train36.py
# sed -i 's/data_XXX/data_36/g' o2_eval36.py
# sed -i 's/data_XXX/data_36/g' o2_project36.py
# qsub run36.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.4.1.2.4' > data_37.txt
# cp run.pbs run37.pbs
# sed -i 's/o2_train.py/o2_train37.py/g' run37.pbs
# sed -i 's/o2_eval.py/o2_eval37.py/g' run37.pbs
# sed -i 's/o2_project.py/o2_project37.py/g' run37.pbs
# sed -i 's/map_o2_XXX/map_o2_37/g' run37.pbs
# cp o2_train.py o2_train37.py
# cp o2_eval.py o2_eval37.py
# cp o2_project.py o2_project37.py
# sed -i 's/data_XXX/data_37/g' o2_train37.py
# sed -i 's/data_XXX/data_37/g' o2_eval37.py
# sed -i 's/data_XXX/data_37/g' o2_project37.py
# qsub run37.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.4.1.3.4' > data_38.txt
# cp run.pbs run38.pbs
# sed -i 's/o2_train.py/o2_train38.py/g' run38.pbs
# sed -i 's/o2_eval.py/o2_eval38.py/g' run38.pbs
# sed -i 's/o2_project.py/o2_project38.py/g' run38.pbs
# sed -i 's/map_o2_XXX/map_o2_38/g' run38.pbs
# cp o2_train.py o2_train38.py
# cp o2_eval.py o2_eval38.py
# cp o2_project.py o2_project38.py
# sed -i 's/data_XXX/data_38/g' o2_train38.py
# sed -i 's/data_XXX/data_38/g' o2_eval38.py
# sed -i 's/data_XXX/data_38/g' o2_project38.py
# qsub run38.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.4.1.4.4' > data_39.txt
# cp run.pbs run39.pbs
# sed -i 's/o2_train.py/o2_train39.py/g' run39.pbs
# sed -i 's/o2_eval.py/o2_eval39.py/g' run39.pbs
# sed -i 's/o2_project.py/o2_project39.py/g' run39.pbs
# sed -i 's/map_o2_XXX/map_o2_39/g' run39.pbs
# cp o2_train.py o2_train39.py
# cp o2_eval.py o2_eval39.py
# cp o2_project.py o2_project39.py
# sed -i 's/data_XXX/data_39/g' o2_train39.py
# sed -i 's/data_XXX/data_39/g' o2_eval39.py
# sed -i 's/data_XXX/data_39/g' o2_project39.py
# qsub run39.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.4.1.2.4' > data_40.txt
# cp run.pbs run40.pbs
# sed -i 's/o2_train.py/o2_train40.py/g' run40.pbs
# sed -i 's/o2_eval.py/o2_eval40.py/g' run40.pbs
# sed -i 's/o2_project.py/o2_project40.py/g' run40.pbs
# sed -i 's/map_o2_XXX/map_o2_40/g' run40.pbs
# cp o2_train.py o2_train40.py
# cp o2_eval.py o2_eval40.py
# cp o2_project.py o2_project40.py
# sed -i 's/data_XXX/data_40/g' o2_train40.py
# sed -i 's/data_XXX/data_40/g' o2_eval40.py
# sed -i 's/data_XXX/data_40/g' o2_project40.py
# qsub run40.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.4.1.3.4' > data_41.txt
# cp run.pbs run41.pbs
# sed -i 's/o2_train.py/o2_train41.py/g' run41.pbs
# sed -i 's/o2_eval.py/o2_eval41.py/g' run41.pbs
# sed -i 's/o2_project.py/o2_project41.py/g' run41.pbs
# sed -i 's/map_o2_XXX/map_o2_41/g' run41.pbs
# cp o2_train.py o2_train41.py
# cp o2_eval.py o2_eval41.py
# cp o2_project.py o2_project41.py
# sed -i 's/data_XXX/data_41/g' o2_train41.py
# sed -i 's/data_XXX/data_41/g' o2_eval41.py
# sed -i 's/data_XXX/data_41/g' o2_project41.py
# qsub run41.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.4.1.4.4' > data_42.txt
# cp run.pbs run42.pbs
# sed -i 's/o2_train.py/o2_train42.py/g' run42.pbs
# sed -i 's/o2_eval.py/o2_eval42.py/g' run42.pbs
# sed -i 's/o2_project.py/o2_project42.py/g' run42.pbs
# sed -i 's/map_o2_XXX/map_o2_42/g' run42.pbs
# cp o2_train.py o2_train42.py
# cp o2_eval.py o2_eval42.py
# cp o2_project.py o2_project42.py
# sed -i 's/data_XXX/data_42/g' o2_train42.py
# sed -i 's/data_XXX/data_42/g' o2_eval42.py
# sed -i 's/data_XXX/data_42/g' o2_project42.py
# qsub run42.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.4.1.2.4' > data_43.txt
# cp run.pbs run43.pbs
# sed -i 's/o2_train.py/o2_train43.py/g' run43.pbs
# sed -i 's/o2_eval.py/o2_eval43.py/g' run43.pbs
# sed -i 's/o2_project.py/o2_project43.py/g' run43.pbs
# sed -i 's/map_o2_XXX/map_o2_43/g' run43.pbs
# cp o2_train.py o2_train43.py
# cp o2_eval.py o2_eval43.py
# cp o2_project.py o2_project43.py
# sed -i 's/data_XXX/data_43/g' o2_train43.py
# sed -i 's/data_XXX/data_43/g' o2_eval43.py
# sed -i 's/data_XXX/data_43/g' o2_project43.py
# qsub run43.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.4.1.3.4' > data_44.txt
# cp run.pbs run44.pbs
# sed -i 's/o2_train.py/o2_train44.py/g' run44.pbs
# sed -i 's/o2_eval.py/o2_eval44.py/g' run44.pbs
# sed -i 's/o2_project.py/o2_project44.py/g' run44.pbs
# sed -i 's/map_o2_XXX/map_o2_44/g' run44.pbs
# cp o2_train.py o2_train44.py
# cp o2_eval.py o2_eval44.py
# cp o2_project.py o2_project44.py
# sed -i 's/data_XXX/data_44/g' o2_train44.py
# sed -i 's/data_XXX/data_44/g' o2_eval44.py
# sed -i 's/data_XXX/data_44/g' o2_project44.py
# qsub run44.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.4.1.4.4' > data_45.txt
# cp run.pbs run45.pbs
# sed -i 's/o2_train.py/o2_train45.py/g' run45.pbs
# sed -i 's/o2_eval.py/o2_eval45.py/g' run45.pbs
# sed -i 's/o2_project.py/o2_project45.py/g' run45.pbs
# sed -i 's/map_o2_XXX/map_o2_45/g' run45.pbs
# cp o2_train.py o2_train45.py
# cp o2_eval.py o2_eval45.py
# cp o2_project.py o2_project45.py
# sed -i 's/data_XXX/data_45/g' o2_train45.py
# sed -i 's/data_XXX/data_45/g' o2_eval45.py
# sed -i 's/data_XXX/data_45/g' o2_project45.py
# qsub run45.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.4.1.2.4' > data_46.txt
# cp run.pbs run46.pbs
# sed -i 's/o2_train.py/o2_train46.py/g' run46.pbs
# sed -i 's/o2_eval.py/o2_eval46.py/g' run46.pbs
# sed -i 's/o2_project.py/o2_project46.py/g' run46.pbs
# sed -i 's/map_o2_XXX/map_o2_46/g' run46.pbs
# cp o2_train.py o2_train46.py
# cp o2_eval.py o2_eval46.py
# cp o2_project.py o2_project46.py
# sed -i 's/data_XXX/data_46/g' o2_train46.py
# sed -i 's/data_XXX/data_46/g' o2_eval46.py
# sed -i 's/data_XXX/data_46/g' o2_project46.py
# qsub run46.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.4.1.3.4' > data_47.txt
# cp run.pbs run47.pbs
# sed -i 's/o2_train.py/o2_train47.py/g' run47.pbs
# sed -i 's/o2_eval.py/o2_eval47.py/g' run47.pbs
# sed -i 's/o2_project.py/o2_project47.py/g' run47.pbs
# sed -i 's/map_o2_XXX/map_o2_47/g' run47.pbs
# cp o2_train.py o2_train47.py
# cp o2_eval.py o2_eval47.py
# cp o2_project.py o2_project47.py
# sed -i 's/data_XXX/data_47/g' o2_train47.py
# sed -i 's/data_XXX/data_47/g' o2_eval47.py
# sed -i 's/data_XXX/data_47/g' o2_project47.py
# qsub run47.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.4.1.4.4' > data_48.txt
# cp run.pbs run48.pbs
# sed -i 's/o2_train.py/o2_train48.py/g' run48.pbs
# sed -i 's/o2_eval.py/o2_eval48.py/g' run48.pbs
# sed -i 's/o2_project.py/o2_project48.py/g' run48.pbs
# sed -i 's/map_o2_XXX/map_o2_48/g' run48.pbs
# cp o2_train.py o2_train48.py
# cp o2_eval.py o2_eval48.py
# cp o2_project.py o2_project48.py
# sed -i 's/data_XXX/data_48/g' o2_train48.py
# sed -i 's/data_XXX/data_48/g' o2_eval48.py
# sed -i 's/data_XXX/data_48/g' o2_project48.py
# qsub run48.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.5.1.2.4' > data_49.txt
# cp run.pbs run49.pbs
# sed -i 's/o2_train.py/o2_train49.py/g' run49.pbs
# sed -i 's/o2_eval.py/o2_eval49.py/g' run49.pbs
# sed -i 's/o2_project.py/o2_project49.py/g' run49.pbs
# sed -i 's/map_o2_XXX/map_o2_49/g' run49.pbs
# cp o2_train.py o2_train49.py
# cp o2_eval.py o2_eval49.py
# cp o2_project.py o2_project49.py
# sed -i 's/data_XXX/data_49/g' o2_train49.py
# sed -i 's/data_XXX/data_49/g' o2_eval49.py
# sed -i 's/data_XXX/data_49/g' o2_project49.py
# qsub run49.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.5.1.3.4' > data_50.txt
# cp run.pbs run50.pbs
# sed -i 's/o2_train.py/o2_train50.py/g' run50.pbs
# sed -i 's/o2_eval.py/o2_eval50.py/g' run50.pbs
# sed -i 's/o2_project.py/o2_project50.py/g' run50.pbs
# sed -i 's/map_o2_XXX/map_o2_50/g' run50.pbs
# cp o2_train.py o2_train50.py
# cp o2_eval.py o2_eval50.py
# cp o2_project.py o2_project50.py
# sed -i 's/data_XXX/data_50/g' o2_train50.py
# sed -i 's/data_XXX/data_50/g' o2_eval50.py
# sed -i 's/data_XXX/data_50/g' o2_project50.py
# qsub run50.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.1.5.1.4.4' > data_51.txt
# cp run.pbs run51.pbs
# sed -i 's/o2_train.py/o2_train51.py/g' run51.pbs
# sed -i 's/o2_eval.py/o2_eval51.py/g' run51.pbs
# sed -i 's/o2_project.py/o2_project51.py/g' run51.pbs
# sed -i 's/map_o2_XXX/map_o2_51/g' run51.pbs
# cp o2_train.py o2_train51.py
# cp o2_eval.py o2_eval51.py
# cp o2_project.py o2_project51.py
# sed -i 's/data_XXX/data_51/g' o2_train51.py
# sed -i 's/data_XXX/data_51/g' o2_eval51.py
# sed -i 's/data_XXX/data_51/g' o2_project51.py
# qsub run51.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.5.1.2.4' > data_52.txt
# cp run.pbs run52.pbs
# sed -i 's/o2_train.py/o2_train52.py/g' run52.pbs
# sed -i 's/o2_eval.py/o2_eval52.py/g' run52.pbs
# sed -i 's/o2_project.py/o2_project52.py/g' run52.pbs
# sed -i 's/map_o2_XXX/map_o2_52/g' run52.pbs
# cp o2_train.py o2_train52.py
# cp o2_eval.py o2_eval52.py
# cp o2_project.py o2_project52.py
# sed -i 's/data_XXX/data_52/g' o2_train52.py
# sed -i 's/data_XXX/data_52/g' o2_eval52.py
# sed -i 's/data_XXX/data_52/g' o2_project52.py
# qsub run52.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.5.1.3.4' > data_53.txt
# cp run.pbs run53.pbs
# sed -i 's/o2_train.py/o2_train53.py/g' run53.pbs
# sed -i 's/o2_eval.py/o2_eval53.py/g' run53.pbs
# sed -i 's/o2_project.py/o2_project53.py/g' run53.pbs
# sed -i 's/map_o2_XXX/map_o2_53/g' run53.pbs
# cp o2_train.py o2_train53.py
# cp o2_eval.py o2_eval53.py
# cp o2_project.py o2_project53.py
# sed -i 's/data_XXX/data_53/g' o2_train53.py
# sed -i 's/data_XXX/data_53/g' o2_eval53.py
# sed -i 's/data_XXX/data_53/g' o2_project53.py
# qsub run53.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.1.5.1.4.4' > data_54.txt
# cp run.pbs run54.pbs
# sed -i 's/o2_train.py/o2_train54.py/g' run54.pbs
# sed -i 's/o2_eval.py/o2_eval54.py/g' run54.pbs
# sed -i 's/o2_project.py/o2_project54.py/g' run54.pbs
# sed -i 's/map_o2_XXX/map_o2_54/g' run54.pbs
# cp o2_train.py o2_train54.py
# cp o2_eval.py o2_eval54.py
# cp o2_project.py o2_project54.py
# sed -i 's/data_XXX/data_54/g' o2_train54.py
# sed -i 's/data_XXX/data_54/g' o2_eval54.py
# sed -i 's/data_XXX/data_54/g' o2_project54.py
# qsub run54.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.5.1.2.4' > data_55.txt
# cp run.pbs run55.pbs
# sed -i 's/o2_train.py/o2_train55.py/g' run55.pbs
# sed -i 's/o2_eval.py/o2_eval55.py/g' run55.pbs
# sed -i 's/o2_project.py/o2_project55.py/g' run55.pbs
# sed -i 's/map_o2_XXX/map_o2_55/g' run55.pbs
# cp o2_train.py o2_train55.py
# cp o2_eval.py o2_eval55.py
# cp o2_project.py o2_project55.py
# sed -i 's/data_XXX/data_55/g' o2_train55.py
# sed -i 's/data_XXX/data_55/g' o2_eval55.py
# sed -i 's/data_XXX/data_55/g' o2_project55.py
# qsub run55.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.5.1.3.4' > data_56.txt
# cp run.pbs run56.pbs
# sed -i 's/o2_train.py/o2_train56.py/g' run56.pbs
# sed -i 's/o2_eval.py/o2_eval56.py/g' run56.pbs
# sed -i 's/o2_project.py/o2_project56.py/g' run56.pbs
# sed -i 's/map_o2_XXX/map_o2_56/g' run56.pbs
# cp o2_train.py o2_train56.py
# cp o2_eval.py o2_eval56.py
# cp o2_project.py o2_project56.py
# sed -i 's/data_XXX/data_56/g' o2_train56.py
# sed -i 's/data_XXX/data_56/g' o2_eval56.py
# sed -i 's/data_XXX/data_56/g' o2_project56.py
# qsub run56.pbs
# sleep 3
# #--------------------------------------------------------
# echo '1.2.5.1.4.4' > data_57.txt
# cp run.pbs run57.pbs
# sed -i 's/o2_train.py/o2_train57.py/g' run57.pbs
# sed -i 's/o2_eval.py/o2_eval57.py/g' run57.pbs
# sed -i 's/o2_project.py/o2_project57.py/g' run57.pbs
# sed -i 's/map_o2_XXX/map_o2_57/g' run57.pbs
# cp o2_train.py o2_train57.py
# cp o2_eval.py o2_eval57.py
# cp o2_project.py o2_project57.py
# sed -i 's/data_XXX/data_57/g' o2_train57.py
# sed -i 's/data_XXX/data_57/g' o2_eval57.py
# sed -i 's/data_XXX/data_57/g' o2_project57.py
# qsub run57.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.5.1.2.4' > data_58.txt
# cp run.pbs run58.pbs
# sed -i 's/o2_train.py/o2_train58.py/g' run58.pbs
# sed -i 's/o2_eval.py/o2_eval58.py/g' run58.pbs
# sed -i 's/o2_project.py/o2_project58.py/g' run58.pbs
# sed -i 's/map_o2_XXX/map_o2_58/g' run58.pbs
# cp o2_train.py o2_train58.py
# cp o2_eval.py o2_eval58.py
# cp o2_project.py o2_project58.py
# sed -i 's/data_XXX/data_58/g' o2_train58.py
# sed -i 's/data_XXX/data_58/g' o2_eval58.py
# sed -i 's/data_XXX/data_58/g' o2_project58.py
# qsub run58.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.5.1.3.4' > data_59.txt
# cp run.pbs run59.pbs
# sed -i 's/o2_train.py/o2_train59.py/g' run59.pbs
# sed -i 's/o2_eval.py/o2_eval59.py/g' run59.pbs
# sed -i 's/o2_project.py/o2_project59.py/g' run59.pbs
# sed -i 's/map_o2_XXX/map_o2_59/g' run59.pbs
# cp o2_train.py o2_train59.py
# cp o2_eval.py o2_eval59.py
# cp o2_project.py o2_project59.py
# sed -i 's/data_XXX/data_59/g' o2_train59.py
# sed -i 's/data_XXX/data_59/g' o2_eval59.py
# sed -i 's/data_XXX/data_59/g' o2_project59.py
# qsub run59.pbs
# sleep 3
# #--------------------------------------------------------
# echo '2.2.5.1.4.4' > data_60.txt
# cp run.pbs run60.pbs
# sed -i 's/o2_train.py/o2_train60.py/g' run60.pbs
# sed -i 's/o2_eval.py/o2_eval60.py/g' run60.pbs
# sed -i 's/o2_project.py/o2_project60.py/g' run60.pbs
# sed -i 's/map_o2_XXX/map_o2_60/g' run60.pbs
# cp o2_train.py o2_train60.py
# cp o2_eval.py o2_eval60.py
# cp o2_project.py o2_project60.py
# sed -i 's/data_XXX/data_60/g' o2_train60.py
# sed -i 's/data_XXX/data_60/g' o2_eval60.py
# sed -i 's/data_XXX/data_60/g' o2_project60.py
# qsub run60.pbs
# sleep 3
# #--------------------------------------------------------
